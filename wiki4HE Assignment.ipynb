# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
wiki = pd.read_csv('wiki4HE.csv', sep=';')
wiki.head()
# Out:
#    AGE  GENDER DOMAIN  PhD YEARSEXP  UNIVERSITY UOC_POSITION OTHER_POSITION  \
# 0   40       0      2    1       14           1            2              ?
# 1   42       0      5    1       18           1            2              ?
# 2   37       0      4    1       13           1            3              ?
# 3   40       0      4    0       13           1            3              ?
# 4   51       0      6    0        8           1            3              ?
#
#   OTHERSTATUS USERWIKI  ... BI2 Inc1 Inc2 Inc3 Inc4 Exp1 Exp2 Exp3 Exp4 Exp5
# 0           ?        0  ...   3    5    5    5    5    4    4    4    1    2
# 1           ?        0  ...   2    4    4    3    4    2    2    4    2    4
# 2           ?        0  ...   1    5    3    5    5    2    2    2    1    3
# 3           ?        0  ...   3    3    4    4    3    4    4    3    3    4
# 4           ?        1  ...   5    5    5    4    4    5    5    5    4    4
#
# [5 rows x 53 columns]

# %%
wiki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 53 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AGE             913 non-null    int64
#  1   GENDER          913 non-null    int64
#  2   DOMAIN          913 non-null    object
#  3   PhD             913 non-null    int64
#  4   YEARSEXP        913 non-null    object
#  5   UNIVERSITY      913 non-null    int64
#  6   UOC_POSITION    913 non-null    object
#  7   OTHER_POSITION  913 non-null    object
#  8   OTHERSTATUS     913 non-null    object
#  9   USERWIKI        913 non-null    object
#  10  PU1             913 non-null    object
#  11  PU2             913 non-null    object
#  12  PU3             913 non-null    object
#  13  PEU1            913 non-null    object
#  14  PEU2            913 non-null    object
#  15  PEU3            913 non-null    object
#  16  ENJ1            913 non-null    object
# ...

# %% [markdown]
# Rearranging columns to make all the object columns together

# %%
third_column = wiki.pop('PhD')

# %%
wiki.insert(2, 'PhD', third_column)

# %%
fourth_column = wiki.pop('UNIVERSITY')

# %%
wiki.insert(3, 'UNIVERSITY', fourth_column)

# %%
wiki.head()
# Out:
#    AGE  GENDER  PhD  UNIVERSITY DOMAIN YEARSEXP UOC_POSITION OTHER_POSITION  \
# 0   40       0    1           1      2       14            2              ?
# 1   42       0    1           1      5       18            2              ?
# 2   37       0    1           1      4       13            3              ?
# 3   40       0    0           1      4       13            3              ?
# 4   51       0    0           1      6        8            3              ?
#
#   OTHERSTATUS USERWIKI  ... BI2 Inc1 Inc2 Inc3 Inc4 Exp1 Exp2 Exp3 Exp4 Exp5
# 0           ?        0  ...   3    5    5    5    5    4    4    4    1    2
# 1           ?        0  ...   2    4    4    3    4    2    2    4    2    4
# 2           ?        0  ...   1    5    3    5    5    2    2    2    1    3
# 3           ?        0  ...   3    3    4    4    3    4    4    3    3    4
# 4           ?        1  ...   5    5    5    4    4    5    5    5    4    4
#
# [5 rows x 53 columns]

# %%
for c in wiki.columns[4:]:

    wiki[c] = (pd.to_numeric(wiki[c], errors='coerce'))

# %%
wiki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 53 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AGE             913 non-null    int64
#  1   GENDER          913 non-null    int64
#  2   PhD             913 non-null    int64
#  3   UNIVERSITY      913 non-null    int64
#  4   DOMAIN          911 non-null    float64
#  5   YEARSEXP        890 non-null    float64
#  6   UOC_POSITION    800 non-null    float64
#  7   OTHER_POSITION  652 non-null    float64
#  8   OTHERSTATUS     373 non-null    float64
#  9   USERWIKI        909 non-null    float64
#  10  PU1             906 non-null    float64
#  11  PU2             902 non-null    float64
#  12  PU3             908 non-null    float64
#  13  PEU1            909 non-null    float64
#  14  PEU2            899 non-null    float64
#  15  PEU3            816 non-null    float64
#  16  ENJ1            906 non-null    float64
# ...

# %%
wiki.head()
# Out:
#    AGE  GENDER  PhD  UNIVERSITY  DOMAIN  YEARSEXP  UOC_POSITION  \
# 0   40       0    1           1     2.0      14.0           2.0
# 1   42       0    1           1     5.0      18.0           2.0
# 2   37       0    1           1     4.0      13.0           3.0
# 3   40       0    0           1     4.0      13.0           3.0
# 4   51       0    0           1     6.0       8.0           3.0
#
#    OTHER_POSITION  OTHERSTATUS  USERWIKI  ...  BI2  Inc1  Inc2  Inc3  Inc4  \
# 0             NaN          NaN       0.0  ...  3.0   5.0   5.0   5.0   5.0
# 1             NaN          NaN       0.0  ...  2.0   4.0   4.0   3.0   4.0
# 2             NaN          NaN       0.0  ...  1.0   5.0   3.0   5.0   5.0
# 3             NaN          NaN       0.0  ...  3.0   3.0   4.0   4.0   3.0
# 4             NaN          NaN       1.0  ...  5.0   5.0   5.0   4.0   4.0
#
#    Exp1  Exp2  Exp3  Exp4  Exp5
# 0   4.0   4.0   4.0   1.0   2.0
# 1   2.0   2.0   4.0   2.0   4.0
# ...

# %%
wiki.isna().sum()
# Out:
# AGE                 0
# GENDER              0
# PhD                 0
# UNIVERSITY          0
# DOMAIN              2
# YEARSEXP           23
# UOC_POSITION      113
# OTHER_POSITION    261
# OTHERSTATUS       540
# USERWIKI            4
# PU1                 7
# PU2                11
# PU3                 5
# PEU1                4
# PEU2               14
# PEU3               97
# ENJ1                7
# ENJ2               17
# Qu1                 7
# Qu2                10
# Qu3                15
# Qu4                22
# Qu5                29
# Vis1               72
# Vis2              117
# Vis3                8
# Im1                22
# Im2                20
# Im3                57
# SA1                11
# SA2                12
# SA3                11
# Use1               14
# Use2               17
# Use3                9
# Use4               23
# Use5               15
# Pf1                11
# Pf2                 6
# Pf3                14
# JR1                27
# ...

# %%
wiki.drop(columns='OTHERSTATUS')
# Out:
#      AGE  GENDER  PhD  UNIVERSITY  DOMAIN  YEARSEXP  UOC_POSITION  \
# 0     40       0    1           1     2.0      14.0           2.0
# 1     42       0    1           1     5.0      18.0           2.0
# 2     37       0    1           1     4.0      13.0           3.0
# 3     40       0    0           1     4.0      13.0           3.0
# 4     51       0    0           1     6.0       8.0           3.0
# ..   ...     ...  ...         ...     ...       ...           ...
# 908   43       0    1           2     5.0      21.0           NaN
# 909   53       0    0           2     6.0      25.0           NaN
# 910   39       0    1           2     5.0       9.0           NaN
# 911   40       0    1           2     3.0      10.0           NaN
# 912   41       1    1           2     3.0      12.0           NaN
#
#      OTHER_POSITION  USERWIKI  PU1  ...  BI2  Inc1  Inc2  Inc3  Inc4  Exp1  \
# 0               NaN       0.0  4.0  ...  3.0   5.0   5.0   5.0   5.0   4.0
# ...

# %%
wiki['YEARSEXP'].fillna(wiki['YEARSEXP'].mode()[0], inplace=True)

# %%
for c in wiki.columns:

    wiki[c] = (wiki[c].fillna(wiki[c].mode()[0])).astype(int)

# %%
wiki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 53 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AGE             913 non-null    int32
#  1   GENDER          913 non-null    int32
#  2   PhD             913 non-null    int32
#  3   UNIVERSITY      913 non-null    int32
#  4   DOMAIN          913 non-null    int32
#  5   YEARSEXP        913 non-null    int32
#  6   UOC_POSITION    913 non-null    int32
#  7   OTHER_POSITION  913 non-null    int32
#  8   OTHERSTATUS     913 non-null    int32
#  9   USERWIKI        913 non-null    int32
#  10  PU1             913 non-null    int32
#  11  PU2             913 non-null    int32
#  12  PU3             913 non-null    int32
#  13  PEU1            913 non-null    int32
#  14  PEU2            913 non-null    int32
#  15  PEU3            913 non-null    int32
#  16  ENJ1            913 non-null    int32
# ...
